# %%
import pandas as pd
import sys
sys.path.append("C:\\Users\\Addiel\\Desktop\\LogsPrinting\\src")
from db_oracle import DB

# %%
db = DB()

# %%
data = pd.DataFrame.from_dict(db.exec_dml('''select * from logminerFiltered where username <> 'UNKNOWN' and
username <> 'SYS' and table_space <> 'None' and table_space <> 'UNKNOW' and table_name <> 'None' '''))

# %%
data.head(16565)
# Out:
#    USERNAME OPERATION TABLE_NAME TABLE_SPACE SEG_OWNER     DATE_      TIME_  \
# 0     USER1    INSERT       AUD$      SYSTEM       SYS  24/10/18   5:24:301
# 1     USER1    UPDATE       AUD$      SYSTEM       SYS  24/10/18   5:24:301
# 2     USER1    INSERT       OBJ$      SYSTEM       SYS  24/10/18   9:10:299
# 3     USER1    INSERT       SEG$      SYSTEM       SYS  24/10/18   9:32:296
# 4     USER1    INSERT       TAB$      SYSTEM       SYS  24/10/18   9:10:299
# 5     USER1    INSERT       COL$      SYSTEM       SYS  24/10/18   9:10:299
# 6     USER1    INSERT       COL$      SYSTEM       SYS  24/10/18   9:10:299
# 7     USER1    INSERT       COL$      SYSTEM       SYS  24/10/18   9:10:299
# 8     USER1    UPDATE       SEG$      SYSTEM       SYS  24/10/18   9:10:299
# 9     USER1    INSERT         T1         TS1     USER1  24/10/18    8:1:306
# 10    USER1    INSERT         T1         TS1     USER1  24/10/18    8:1:306
# ...

# %%
data.shape
# Out:
# (74, 9)

# %%
# %matplotlib inline
data.groupby(['DATE_'])['DATE_'].count().plot(kind="bar", x="DATE")

# %%
# %matplotlib inline
data.groupby(['TIME_'])['TIME_'].count().plot(kind="bar", x="TIME_")

# %%
# %matplotlib inline
data.groupby(['DATE_'])['DATE_'].count().plot(kind="bar", x="DATE")

# %%
# %matplotlib inline
data.groupby(['TABLE_NAME'])['TABLE_NAME'].count().plot(kind="bar", x="OPERATION")

# %%
# %matplotlib inline
data.groupby(['TABLE_SPACE'])['TABLE_SPACE'].count().plot(kind="bar", x="SEG_OWNER")

# %%
data.groupby(['USERNAME'])['USERNAME'].count().plot(kind="bar", x="USERNAME")

# %%
data.groupby(['OPERATION'])['OPERATION'].count().plot(kind="bar", x="OPERATION")
